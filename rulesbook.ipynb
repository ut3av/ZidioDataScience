# %% [markdown]
# command line - OS using text
# Text Command
# ----------------------------
# Rules:
# a-z , A- Z
# 0 to 9
# _ underscore used in special cases
#      okay never ever start any name with number for example 1name = " Anamika " , so if we gonna print them their is always a syntax error
#     For exmaple :
#                 1name = " Anamika "
# print(1name)  'it will not run '
#     but if we write our code in this format
# name_1 = " Anamika"
# print(name_1)
# - In variables no extra space required for: nmae_ 1 (not allowed)
# and if you want space use underscore_ , for example: name_1 (allowed)
# Apart from underscore No special characters were used. If used then the code will not run.

# %% [markdown]
# name_1 = " Anamika"
# print(name_1)
# a= 10
# print(a)
# a=20
# print(a)
# a= 50
# b= a
# print(a, b)

# %% [markdown]
# Let's talk about data:-
# Data is a source of information. Whethers it's about someone age, and company data, or anything.
# Now we gonna discuss about data types:-
# a) Numeric Data:-
#   1. int (whole number, no decimal in it )
# for example:- a= 10
#               b= -50
#               c= 200
#   2. flot( No. are written in decimnal form)
# for example:- price= 99.99
#  height=5.3
# temp=36.7
# b) String Data (str) :-
# Okay so whatever we write between "", ''; that is considered under in string or str or text data .
#     for example:-
# name= " Palak"
# age=  " 23"
# height= '5.3'
# data= "pharmacist"
# print( name, age, height, data)

# %% [markdown]
# name= " Palak"
# age=  " 23"
# height= '5.3'
# data= "pharmacist"
# print( name, age, height, data)

# %% [markdown]
# Why we write string under double quote, because if we don't use "",'', the computer will not understand and take it as a variable.
# In python there is no  seperate char data type. Instead, a single character is simply treated as a string of length one.
#
# * python uses the str class for both single character and multi- character text.
# C) Boolean Condition :-
# is_paridhi good= True
# is_paridhi not good = False
# print(is_paridhi good)
# None = No value, we use none when no value is assigned

# %%
x=10
is_learn= True
result= None
print(type(x))
print(type(is_learn))
print(type(result))
# Out:
# <class 'int'>
# <class 'bool'>
# <class 'NoneType'>

# %%
name= input("pihu")
print("Hi",(name))
# Out:
# pihu 78
# Hi 78

# %% [markdown]
# input() hamesha string deta hai

# %% [markdown]
# whenever you need to convert string into integer or float = That is know as type conversion we can write int simply before parenthesis and then it is
# converted into integer for example:

# %%
x= input("Enter number1: ")
y= input(" Enter number2: ")
print(x+y)
# Out:
# Enter number1:  20
#  Enter number2:  50
# 2050

# %% [markdown]
# Now I showing you how to convert any string into inter or float by simply applying int before input

# %%
x= int(input("Enter number1:  "))
y= int(input("Enter number2:  "))
print(x+y)
# Out:
# Enter number1:   20
# Enter number2:   50
# 70

# %% [markdown]
# Now I'm showing you another example of using float before input to convert string into float

# %%
x=float(input("Enter number1:  "))
y= float(input("Enter number2:  "))
print(x+y)
# Out:
# Enter number1:   1.258
# Enter number2:   3.589
# 4.8469999999999995

# %% [markdown]
# Now we are going to study about OPERATORS :
# ###  OPERATORS

# %% [markdown]
# Why we need operators ?
# As we are storing data, but we are not doing anything such thing which help do some some work or to perform any data work.
# Illustrate:-
# Simple Interest formula = (principle*rate OF INTEREST * time/100)
#
# Let's say we write 1+1 so the plus sign is (+) that is known as operators and the valus in which this speacial sign used is know as 'operants'.
# An operator is a symbol used to perform operations on variables or value.
# For example

# %%
a= 10
b=85
print(a+b)
here + is an operator
# Out:
# 95

# %% [markdown]
# ### Types of Operators

# %% [markdown]
# 1. Arithmetic Operators
# 2. Assignment Operators
# 3. Comparison Operators
# 4. Logical Operators
# 5. Identity Operators
# 6. Membership Operators
# 7. Bitwise Operators

# %% [markdown]
# ### Arithmetic Operators
# Used for math operations.
# Operators            Meaning                      Example
# +                    Addition                  10+5= 15
# -                    Substractions             10-5= 5
# *                    Multiply                   10*5= 50
# /                    Division                   10/5= 2.0
# //                  Floor division             10//3= 3
# %                   Modulus(reminder)          10%3=1
# **                  Exponential(Power)         2**3= 8

# %%
print(10+5)
print(10%5)
print(10//3)
print(10/5)
print(10**5)
# Out:
# 15
# 0
# 3
# 2.0
# 100000

# %%
print("Hi"+"Python")
print("Hi"+ "Palak")
print(10+10.20)
print("10"*3)
print(10*3)
# Out:
# HiPython
# HiPalak
# 20.2
# 101010
# 30

# %% [markdown]
# ### Assignment Operators

# %% [markdown]
# # used to assign values.
# =  assign
# += add and assign
# -= substract and assign
# *= multiply and assign
# /= divide and assign

# %%
x = 5 
x += 3
print(x)
x -= 2
print(x) 
x *= 4
print(x) 
x /=
# Out:
#   Cell In[7], line 2
#     print(x = x+= 3)
#                ^
# SyntaxError: invalid syntax
